# %%
# %pip install xmitgcm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xmitgcm in ./.local/lib/python3.11/site-packages (0.5.2)
# Requirement already satisfied: xarray>=0.11.0 in /opt/jaspy/lib/python3.11/site-packages (from xmitgcm) (2024.7.0)
# Requirement already satisfied: dask>=1.0 in /opt/jaspy/lib/python3.11/site-packages (from xmitgcm) (2024.8.0)
# Requirement already satisfied: cachetools in /opt/jaspy/lib/python3.11/site-packages (from xmitgcm) (5.4.0)
# Requirement already satisfied: click>=8.1 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/jaspy/lib/python3.11/site-packages (from dask>=1.0->xmitgcm) (8.2.0)
# Requirement already satisfied: numpy>=1.23 in /opt/jaspy/lib/python3.11/site-packages (from xarray>=0.11.0->xmitgcm) (1.26.4)
# Requirement already satisfied: pandas>=2.0 in /opt/jaspy/lib/python3.11/site-packages (from xarray>=0.11.0->xmitgcm) (2.2.2)
# Requirement already satisfied: zipp>=0.5 in /opt/jaspy/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask>=1.0->xmitgcm) (3.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/jaspy/lib/python3.11/site-packages (from pandas>=2.0->xarray>=0.11.0->xmitgcm) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/jaspy/lib/python3.11/site-packages (from pandas>=2.0->xarray>=0.11.0->xmitgcm) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/jaspy/lib/python3.11/site-packages (from pandas>=2.0->xarray>=0.11.0->xmitgcm) (2024.1)
# Requirement already satisfied: locket in /opt/jaspy/lib/python3.11/site-packages (from partd>=1.4.0->dask>=1.0->xmitgcm) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/jaspy/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->xarray>=0.11.0->xmitgcm) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xmitgcm
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
from dask.diagnostics import ProgressBar

# %% [markdown]
# ## Loading the datasets

# %%
#Spin Up
data_spinUp = "/gws/nopw/j04/co2clim/uef1/MITgcm/LGM-UF24/TimeVarTair_DiagTracer_SpinUp"
dsSU1 = xmitgcm.open_mdsdataset(data_spinUp, prefix = "dicDiag")
dsSU2 = xmitgcm.open_mdsdataset(data_spinUp, prefix = "Diag4")

# %%
#First Four Runs for the 20000 year periodicity
data_FirstFour20000 = "/gws/nopw/j04/co2clim/uef1/MITgcm/LGM-UF24/TimeVarTair_DiagTracer_FirstFourRuns_20000yr"
dsFF200001 = xmitgcm.open_mdsdataset(data_FirstFour20000, prefix = "DiagTracer")
dsFF200002 = xmitgcm.open_mdsdataset(data_FirstFour20000, prefix = "DiagPhys")

# %%
#loading the SpinUp files data (the same for all periodicities)
daSUTrach01 = dsSU1['TRAC01'].weighted(dsSU1['rA']*dsSU1['hFacC']).mean(['Z', 'XC', 'YC'])
daSUDIC = dsSU1['DICCARB'].weighted(dsSU1['rA']*dsSU1['hFacC']).mean(['Z', 'XC', 'YC'])
daSUAverageDIC = dsSU1['TRAC01'].isel(Z = 0).weighted(dsSU1['rA']).mean(['XC', 'YC'])
daSUTemp = dsSU2['THETA'].weighted(dsSU2['rA']*dsSU2['hFacC']).mean(['Z', 'XC', 'YC'])
daSUAverageTemp = dsSU2['THETA'].isel(Z = 0).weighted(dsSU1['rA']).mean(['XC', 'YC'])
with ProgressBar(): 
    daSUTrach01 = daSUTrach01.load()
with ProgressBar(): 
    daSUDIC = daSUDIC.load()
with ProgressBar(): 
    daSUAverageDIC = daSUAverageDIC.load()
with ProgressBar(): 
    daSUTemp = daSUTemp.load()
with ProgressBar(): 
    daSUAverageTemp = daSUAverageTemp.load()
# Out:
# [########################################] | 100% Completed | 968.81 ms
# [########################################] | 100% Completed | 209.34 ms
# [########################################] | 100% Completed | 312.16 ms
# [########################################] | 100% Completed | 512.78 ms
# [########################################] | 100% Completed | 208.73 ms

# %% [markdown]
# # 20000 year periodicity

# %% [markdown]
# ### Dissolved Inorganic Carbon (DIC) [mol C/m^3] concentration

# %%
daFF20000Trach01 = dsFF200001['TRAC01'].weighted(dsFF200001['rA']*dsFF200001['hFacC']).mean(['Z', 'XC', 'YC'])
with ProgressBar(): 
    daFF20000Trach01 = daFF20000Trach01.load()
# Out:
# [########################################] | 100% Completed | 1.23 sms

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12
daFF20000Trach01.plot()
daSUTrach01.plot()
plt.title("Dissolved Inorganic Carbon (DIC) [mol C/m^3] concentration")
# Out:
# Text(0.5, 1.0, 'Dissolved Inorganic Carbon (DIC) [mol C/m^3] concentration')

# %% [markdown]
# ### Surface Dissolved Inorganic Carbon (DIC) [mol C/m^3] concentration¶

# %%
daFF20000AverageDIC = dsFF200001['TRAC01'].isel(Z = 0).weighted(dsFF200002['rA']).mean(['XC', 'YC'])
with ProgressBar(): 
    daFF20000AverageDIC = daFF20000AverageDIC.load()
# Out:
# [########################################] | 100% Completed | 419.86 ms

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12
daFF20000AverageDIC.plot()
daSUAverageDIC.plot()
plt.title("Surface Dissolved Inorganic Carbon (DIC) [mol C/m^3] concentration")
# Out:
# Text(0.5, 1.0, 'Surface Dissolved Inorganic Carbon (DIC) [mol C/m^3] concentration')

# %% [markdown]
# ### Carbonate chg-biol prod and remin (mol eq/m3/s)

# %%
daFF20000DIC = dsFF200001['DICCARB'].weighted(dsFF200001['rA']*dsFF200001['hFacC']).mean(['Z', 'XC', 'YC'])
with ProgressBar(): 
    daFF20000DIC = daFF20000DIC.load()
# Out:
# [########################################] | 100% Completed | 1.64 sms

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12
daFF20000DIC.plot()
daSUDIC.plot()
plt.title("Carbonate chg-biol prod and remin (mol eq/m3/s)")
# Out:
# Text(0.5, 1.0, 'Carbonate chg-biol prod and remin (mol eq/m3/s)')

# %% [markdown]
# ### Potential Temperature [degC]

# %%
daFF20000Temp = dsFF200002['THETA'].weighted(dsFF200002['rA']*dsFF200002['hFacC']).mean(['Z', 'XC', 'YC'])
with ProgressBar(): 
    daFF20000Temp = daFF20000Temp.load()
# Out:
# [########################################] | 100% Completed | 1.13 sms

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12
daFF20000Temp.plot()
daSUTemp.plot()
plt.title("Potential Temperature [degC]")
# Out:
# Text(0.5, 1.0, 'Potential Temperature [degC]')

# %% [markdown]
# ### Surface Potential Temperature [degC]

# %%
daFF20000AverageTemp = dsFF200002['THETA'].isel(Z=0).weighted(dsFF200002['rA']).mean(['XC', 'YC'])
with ProgressBar(): 
    daFF20000AverageTemp = daFF20000AverageTemp.load()
# Out:
# [########################################] | 100% Completed | 828.14 ms

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12
daFF20000AverageTemp.plot()
daSUAverageTemp.plot()
plt.title("Surface Potential Temperature [degC]")
# Out:
# Text(0.5, 1.0, 'Average Potential Temperature [degC]')
